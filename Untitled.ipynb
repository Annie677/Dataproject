# %%
# Bus Card Type_17

import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os

# %%
bus = pd.read_csv("Bus Card Type_17.csv")
bus.sample(10)
# Out:
#                         Unnamed: 0                     Unnamed: 1  Jul-16  \
# 445                  Night Ride 30        Adult Single Bus Trip 2     NaN
# 225  Outer Sydney Metro Contract 1        Adult Single Bus Trip 2     NaN
# 552                 Night Ride 100                    Child/Youth      14
# 529                  Night Ride 80                    Child/Youth      98
# 289                         NISC 1  Child/Youth Single Bus Trip 2     NaN
# 199       Sydney Metro Contract 14  Child/Youth Single Bus Trip 1     NaN
# 116        Sydney Metro Contract 7                 School Student  93,651
# 266  Outer Sydney Metro Contract 3   Day Pass Child/Youth w/o SAF     NaN
# 330  Outer Sydney Metro Contract 8                          Adult  31,266
# 174       Sydney Metro Contract 12                       Employee     NaN
#
#       Aug-16   Sep-16   Oct-16   Nov-16  Dec-16  Jan-17   Feb-17  ...  Jul-18  \
# ...

# %%
un
